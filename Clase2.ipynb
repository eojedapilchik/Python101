# %% [markdown]
# # Variables

# %%
accion = "Apple"
ticker = "AAPL"
precio = 135
print(precio)

#Case sensitivity de la variables.

precio = 140
print(precio)
# Out:
# 135
# 140

# %%
# constantes
PI = 3.141617

# %% [markdown]
# # Tipos de datos

# %%
#Entero
a = 50
b = 30
c = a + b
print(c)

# Float (Decimal)
e = 10.0
f = 20.0
g = e +f
print(g)

# String (Cadena de caracteres)
nombre = "Luis"
apellido = "Perez" 

# _ como separado de miles
c = 100_000_000
print(c)
# Out:
# 80
# 30.0
# 100000000

# %% [markdown]
# # Operadores

# %%
import math
#potencia
a = 3**2 ## 3 elevado a la potencia 2
#print(a)

b = 9**(1/2)
#print(b)

b = math.sqrt(9)
#print(b)

a = 50
b = 30
c = a/b
#print(c)

#division entero //
total_semanas=120//7
#print(total_semanas)

#Modulo
a = 30
b = 12
c = a % b
print(c)

a = a +1 # resultado 51
a +=1 # a = a +1 resultado 52

b=30
b*=2 # b = b * 2

c= 10
a=50
a+=c #=> a = a + c
#print(a)

a,b = 10,30 # => a= 10  b=30
#print(a)
#print(b)

a,b= 10,20
#print("el valor de a es ",a)
# Out:
# 6
# 10
# 30
# el valor de a es  10

# %% [markdown]
# # Valor presente Neto (ejercicio)

# %%
r = 0.12 # tasa de retorno 
t = 3 # numero de periodos
cupon = 15 # flujos de efectivo / año
inversion_inicial = 120 
valor_nominal = 100 # valor nominal del bono

npv=((valor_nominal+cupon)/(1+r)**(t)) + ((cupon)/(1+r)**(t-1)) + ((cupon)/(1+r)**(t-2)) - inversion_inicial
print("El valor presente neto o valoracion del Proyecto/Bono es :",npv)

total_f = -inversion_inicial+ (cupon*3)+ valor_nominal #balance al final del año 3
print("El valor de la cuenta al final del año 3 seria de: ", total_f)
# Out:
# El valor presente neto o valoracion del Proyecto/Bono es : -12.794506195335302
# El valor de la cuenta al final del año 3 seria de:  25

# %%
#import numpy
# Costo de Oportunidad
ret_spy = 0.09 # 9% de retorno anual del SPY
total_spy =(inversion_inicial*(1+ret_spy)**t)-inversion_inicial
#valor_neto = numpy.npv(r,[-120,15,15,115])
print("La ganancia al final del año 3 serian ",total_spy)
print(valor_neto)
# Out:
# La ganancia al final del año 3 serian  35.40348000000003
# -12.794506195335302

# %% [markdown]
# # Ejercicio de Grafico Velas, Volumen y EMA

# %%
import pandas as pd
import mplfinance as mpf

stock_data = pd.read_csv("UI.csv", index_col=0, parse_dates = True)
print(stock_data.head())

mpf.plot(stock_data, style='yahoo', mav=(9,22,200), volume=True, ylabel="Precios")
# Out:
#                   Open        High         Low       Close   Adj Close  Volume
# Date
# 2020-04-13  154.970001  155.000000  150.889999  153.559998  152.546036   84800
# 2020-04-14  157.699997  161.500000  156.979996  160.570007  159.509766  107200
# 2020-04-15  158.210007  158.210007  151.259995  152.110001  151.105621  143400
# 2020-04-16  153.080002  154.869995  151.789993  153.770004  152.754669   90300
# 2020-04-17  155.889999  158.009995  153.830002  157.919998  156.877243   89100
